# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix_ds = pd.read_csv("DataSet\\Netflix\\NFLX.csv")

# %%
netflix_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
netflix_ds.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
netflix_ds['Date'] = pd.to_datetime(netflix_ds['Date'])

# %%
netflix_ds['Date'].describe()
# Out:
# count                             1009
# mean     2020-02-05 07:30:58.870168320
# min                2018-02-05 00:00:00
# 25%                2019-02-06 00:00:00
# 50%                2020-02-06 00:00:00
# 75%                2021-02-05 00:00:00
# max                2022-02-04 00:00:00
# Name: Date, dtype: object

# %%
netflix_ds['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1009 entries, 0 to 1008
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 1009 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 8.0 KB

# %%
netflix_ds2 = netflix_ds.set_index(netflix_ds['Date'])

# %%
netflix_ds2.head()
# Out:
#                  Date        Open        High         Low       Close  \
# Date
# 2018-02-05 2018-02-05  262.000000  267.899994  250.029999  254.259995
# 2018-02-06 2018-02-06  247.699997  266.700012  245.000000  265.720001
# 2018-02-07 2018-02-07  266.579987  272.450012  264.329987  264.559998
# 2018-02-08 2018-02-08  267.079987  267.619995  250.000000  250.100006
# 2018-02-09 2018-02-09  253.850006  255.800003  236.110001  249.470001
#
#              Adj Close    Volume
# Date
# 2018-02-05  254.259995  11896100
# 2018-02-06  265.720001  12595800
# 2018-02-07  264.559998   8981500
# 2018-02-08  250.100006   9306700
# 2018-02-09  249.470001  16906900

# %%
plt.figure(figsize=(15, 5))
plt.plot(netflix_ds['Date'], netflix_ds['Open'], ) 
plt.grid(True)

# %%
plt.figure(figsize=(15, 5))
plt.plot(netflix_ds['Date'], netflix_ds['Close'], ) 
plt.grid(True)

# %%
netflix_ds.set_index('Date', inplace=True)

fig, axs = plt.subplots(2, 1, constrained_layout = True, figsize=(15, 8))
netflix_ds['Close'].plot(ax=axs[0], xlabel="Date", ylabel="Price", title="Close Prices")
netflix_ds['Open'].plot(ax=axs[1], xlabel="Date", ylabel="Price", title="Open Prices", color="teal")
# Out:
# <Axes: title={'center': 'Open Prices'}, xlabel='Date', ylabel='Price'>

# %%
activision_ds = pd.read_csv("DataSet\\Gaming\\Activision Blizzard.csv")
ea_ds = pd.read_csv("DataSet\\Gaming\\Electronic Arts.csv")
nintendo_ds = pd.read_csv("DataSet\\Gaming\\Nintendo.csv")
ubisoft_ds = pd.read_csv("DataSet\\Gaming\\Ubisoft.csv")

# %%
activision_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5868 entries, 0 to 5867
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5868 non-null   object
#  1   Open       5868 non-null   float64
#  2   High       5868 non-null   float64
#  3   Low        5868 non-null   float64
#  4   Close      5868 non-null   float64
#  5   Adj Close  5868 non-null   float64
#  6   Volume     5868 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 321.0+ KB

# %%
activision_ds['Date'] = pd.to_datetime(activision_ds['Date'])

# %%
activision_ds['Date'].describe()
# Out:
# count                             5868
# mean     2011-09-01 12:04:25.030674688
# min                2000-01-03 00:00:00
# 25%                2005-11-01 18:00:00
# 50%                2011-08-30 12:00:00
# 75%                2017-06-29 06:00:00
# max                2023-04-28 00:00:00
# Name: Date, dtype: object

# %%
ea_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5868 entries, 0 to 5867
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5868 non-null   object
#  1   Open       5868 non-null   float64
#  2   High       5868 non-null   float64
#  3   Low        5868 non-null   float64
#  4   Close      5868 non-null   float64
#  5   Adj Close  5868 non-null   float64
#  6   Volume     5868 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 321.0+ KB

# %%
ea_ds['Date'] = pd.to_datetime(ea_ds['Date'])

# %%
ea_ds['Date'].describe()
# Out:
# count                             5868
# mean     2011-09-01 12:04:25.030674688
# min                2000-01-03 00:00:00
# 25%                2005-11-01 18:00:00
# 50%                2011-08-30 12:00:00
# 75%                2017-06-29 06:00:00
# max                2023-04-28 00:00:00
# Name: Date, dtype: object

# %%
nintendo_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5868 entries, 0 to 5867
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5868 non-null   object
#  1   Open       5868 non-null   float64
#  2   High       5868 non-null   float64
#  3   Low        5868 non-null   float64
#  4   Close      5868 non-null   float64
#  5   Adj Close  5868 non-null   float64
#  6   Volume     5868 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 321.0+ KB

# %%
nintendo_ds['Date'] = pd.to_datetime(nintendo_ds['Date'])

# %%
nintendo_ds['Date'].describe()
# Out:
# count                             5868
# mean     2011-09-01 12:04:25.030674688
# min                2000-01-03 00:00:00
# 25%                2005-11-01 18:00:00
# 50%                2011-08-30 12:00:00
# 75%                2017-06-29 06:00:00
# max                2023-04-28 00:00:00
# Name: Date, dtype: object

# %%
ubisoft_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5997 entries, 0 to 5996
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5997 non-null   object
#  1   Open       5996 non-null   float64
#  2   High       5996 non-null   float64
#  3   Low        5996 non-null   float64
#  4   Close      5996 non-null   float64
#  5   Adj Close  5996 non-null   float64
#  6   Volume     5996 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 328.1+ KB

# %%
ubisoft_ds.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5996.000000  5996.000000  5996.000000  5996.000000  5996.000000
# mean     25.229041    25.622840    24.815629    25.220794    25.220794
# std      24.215199    24.548328    23.878331    24.202843    24.202843
# min       1.900000     1.995000     1.780000     1.922500     1.922500
# 25%       8.125000     8.250000     8.009375     8.125000     8.125000
# 50%      13.000000    13.202500    12.800000    12.995000    12.995000
# 75%      34.237500    34.700001    33.775002    34.332501    34.332501
# max     105.000000   107.900002   103.449997   103.599998   103.599998
#
#              Volume
# count  5.996000e+03
# mean   4.830818e+05
# std    4.804512e+05
# min    0.000000e+00
# 25%    2.325050e+05
# 50%    3.775490e+05
# 75%    5.826998e+05
# max    9.432416e+06

# %%
ubisoft_ds['Date'] = pd.to_datetime(ubisoft_ds['Date'])

# %%
ubisoft_ds['Date'].describe()
# Out:
# count                             5997
# mean     2011-08-18 02:47:07.413707008
# min                2000-01-04 00:00:00
# 25%                2005-10-03 00:00:00
# 50%                2011-08-11 00:00:00
# 75%                2017-06-23 00:00:00
# max                2023-04-28 00:00:00
# Name: Date, dtype: object
